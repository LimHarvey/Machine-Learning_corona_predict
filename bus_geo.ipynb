# %%
import pandas as pd
import numpy as np

# %%
df_bus_time = pd.read_csv('2020_busstaion_timezone.csv', encoding='euckr')
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_bus_time.head()
# Out:
#      사용년월 노선번호             노선명  표준버스정류장ID 버스정류장ARS번호               역명  \
# 0  202001  100  100번(하계동~용산구청)  100000002      01002      창경궁.서울대학교병원
# 1  202001  100  100번(하계동~용산구청)  100000003      01003        명륜3가.성대입구
# 2  202001  100  100번(하계동~용산구청)  100000005      01005    혜화동로터리.여운형활동터
# 3  202001  100  100번(하계동~용산구청)  100000102      01198              원남동
# 4  202001  100  100번(하계동~용산구청)  100000108      01204  종로5가.효제동.김상옥의거터
#
#    00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  19시하차총승객수  20시승차총승객수  \
# 0          1          0         0         0  ...         34         82
# 1          0          0         0         0  ...        156        179
# 2          0          2         0         0  ...        318         24
# 3          0          0         0         0  ...         98        167
# 4         19         34         1         0  ...         56         68
#
#    20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# ...

# %%
df_bus_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468819 entries, 0 to 468818
# Data columns (total 55 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용년월        468819 non-null  int64
#  1   노선번호        468819 non-null  object
#  2   노선명         468819 non-null  object
#  3   표준버스정류장ID   468819 non-null  object
#  4   버스정류장ARS번호  468819 non-null  object
#  5   역명          468819 non-null  object
#  6   00시승차총승객수   468819 non-null  int64
#  7   00시하차총승객수   468819 non-null  int64
#  8   1시승차총승객수    468819 non-null  int64
#  9   1시하차총승객수    468819 non-null  int64
#  10  2시승차총승객수    468819 non-null  int64
#  11  2시하차총승객수    468819 non-null  int64
#  12  3시승차총승객수    468819 non-null  int64
#  13  3시하차총승객수    468819 non-null  int64
#  14  4시승차총승객수    468819 non-null  int64
#  15  4시하차총승객수    468819 non-null  int64
#  16  5시승차총승객수    468819 non-null  int64
#  17  5시하차총승객수    468819 non-null  int64
# ...

# %%
df_bus_time.isnull().sum()
# Out:
# 사용년월          0
# 노선번호          0
# 노선명           0
# 표준버스정류장ID     0
# 버스정류장ARS번호    0
# 역명            0
# 00시승차총승객수     0
# 00시하차총승객수     0
# 1시승차총승객수      0
# 1시하차총승객수      0
# 2시승차총승객수      0
# 2시하차총승객수      0
# 3시승차총승객수      0
# 3시하차총승객수      0
# 4시승차총승객수      0
# 4시하차총승객수      0
# 5시승차총승객수      0
# 5시하차총승객수      0
# 6시승차총승객수      0
# 6시하차총승객수      0
# 7시승차총승객수      0
# 7시하차총승객수      0
# 8시승차총승객수      0
# 8시하차총승객수      0
# 9시승차총승객수      0
# 9시하차총승객수      0
# 10시승차총승객수     0
# 10시하차총승객수     0
# 11시승차총승객수     0
# 11시하차총승객수     0
# 12시승차총승객수     0
# 12시하차총승객수     0
# 13시승차총승객수     0
# 13시하차총승객수     0
# 14시승차총승객수     0
# 14시하차총승객수     0
# 15시승차총승객수     0
# 15시하차총승객수     0
# 16시승차총승객수     0
# 16시하차총승객수     0
# 17시승차총승객수     0
# 17시하차총승객수     0
# 18시승차총승객수     0
# 18시하차총승객수     0
# 19시승차총승객수     0
# 19시하차총승객수     0
# 20시승차총승객수     0
# 20시하차총승객수     0
# 21시승차총승객수     0
# 21시하차총승객수     0
# 22시승차총승객수     0
# 22시하차총승객수     0
# 23시승차총승객수     0
# 23시하차총승객수     0
# 등록일자          0
# ...

# %%
df_bus_time[['표준버스정류장ID','버스정류장ARS번호','역명']].nunique()
# Out:
# 표준버스정류장ID     22890
# 버스정류장ARS번호    12860
# 역명             8296
# dtype: int64

# %%
df_bus_time.rename(columns = {'표준버스정류장ID' : '표준ID'}, inplace = True)

# %%
df_bus_time.표준ID.value_counts()
# Out:
# 101000032    329
# 105000030    324
# 100000388    324
# 100000398    317
# 100000389    314
#             ...
# 121900241      1
# 121900213      1
# 121900209      1
# 121900142      1
# 227000486      1
# Name: 표준ID, Length: 22890, dtype: int64

# %%
df_bus_time[df_bus_time.표준ID == '105000030']
# Out:
#           사용년월  노선번호                     노선명       표준ID 버스정류장ARS번호      역명  \
# 213840  202006   121           121번(화계사~서울숲)  105000030      06114  서울성심병원
# 215073  202006  271B  271B번(용마문화복지센터~국회의사당역)  105000030      06114  서울성심병원
# 224157  202006   202           202번(불암동~후암동)  105000030      06114  서울성심병원
# 224387  202006  3220          3220번(오금동~청량리)  105000030      06114  서울성심병원
# 224577  202006  3216        3216번(오금동~경희의료원)  105000030      06114  서울성심병원
# 224966  202006   120           120번(우이동~청량리)  105000030      06114  서울성심병원
# 225454  202006  1227          1227번(하계동~제기동)  105000030      06114  서울성심병원
# 226033  202006   241         241번(중랑차고지~논현역)  105000030      06114  서울성심병원
# 226936  202006   270        270번(상암동차고지~망우리)  105000030      06114  서울성심병원
#
#         00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  19시하차총승객수  20시승차총승객수  \
# 213840          0          0         0         0  ...        287         91
# ...

# %%
df_bus_time.head()
# Out:
#      사용년월 노선번호             노선명       표준ID 버스정류장ARS번호               역명  \
# 0  202001  100  100번(하계동~용산구청)  100000002      01002      창경궁.서울대학교병원
# 1  202001  100  100번(하계동~용산구청)  100000003      01003        명륜3가.성대입구
# 2  202001  100  100번(하계동~용산구청)  100000005      01005    혜화동로터리.여운형활동터
# 3  202001  100  100번(하계동~용산구청)  100000102      01198              원남동
# 4  202001  100  100번(하계동~용산구청)  100000108      01204  종로5가.효제동.김상옥의거터
#
#    00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  19시하차총승객수  20시승차총승객수  \
# 0          1          0         0         0  ...         34         82
# 1          0          0         0         0  ...        156        179
# 2          0          2         0         0  ...        318         24
# 3          0          0         0         0  ...         98        167
# 4         19         34         1         0  ...         56         68
#
#    20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# ...

# %%
df_bus_coord = pd.read_excel('2020_busstation_coord.xlsx')
df_bus_coord
# Out:
#             표준ID  ARS-ID           정류장명         X좌표        Y좌표   비고
# 0      100000001    1001        종로2가사거리  126.987750  37.569765  NaN
# 1      100000002    1002    창경궁.서울대학교병원  126.996566  37.579183  NaN
# 2      100000003    1003      명륜3가.성대입구  126.998340  37.582671  NaN
# 3      100000004    1004       종로2가.삼일교  126.987613  37.568579  NaN
# 4      100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243  NaN
# ...          ...     ...            ...         ...        ...  ...
# 11275  124000334   25995          우성아파트  127.139339  37.550386  NaN
# 11276  124000333   25996          우성아파트  127.140046  37.550643  NaN
# 11277  124000332   25997           조일약국  127.123596  37.533630  NaN
# 11278  124000331   25998           성내시장  127.125497  37.536155  NaN
# 11279  124000330   25999    천호우체국.로데오거리  127.127337  37.540343  NaN
#
# [11280 rows x 6 columns]

# %%
df_bus_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11280 entries, 0 to 11279
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   표준ID    11280 non-null  int64
#  1   ARS-ID  11280 non-null  int64
#  2   정류장명    11280 non-null  object
#  3   X좌표     11280 non-null  float64
#  4   Y좌표     11280 non-null  float64
#  5   비고      2 non-null      object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 528.9+ KB

# %%
df_bus_coord.nunique()
# Out:
# 표준ID      11280
# ARS-ID    11279
# 정류장명       7004
# X좌표       11276
# Y좌표       11274
# 비고            1
# dtype: int64

# %%
df_bus_tmp=pd.merge(df_bus_time, df_bus_coord, how='inner', on='표준ID')
df_bus_tmp
# Out:
#           사용년월  노선번호                   노선명       표준ID 버스정류장ARS번호  \
# 0       202001   100        100번(하계동~용산구청)  100000002      01002
# 1       202001   102         102번(상계동~동대문)  100000002      01002
# 2       202001   104  104번(강북청소년수련관난나~숭례문)  100000002      01002
# 3       202001   106         106번(의정부~동대문)  100000002      01002
# 4       202001   140       140번(도봉산역~AT센터)  100000002      01002
# ...        ...   ...                   ...        ...        ...
# 404939  202010  4412       4412(개포동~삼성의료원)  122000614      23617
# 404940  202011  3412    3412번(강동공영차고지~우면동)  122000614      23617
# 404941  202011  4412       4412(개포동~삼성의료원)  122000614      23617
# 404942  202012  3412    3412번(강동공영차고지~우면동)  122000614      23617
# 404943  202012  4412       4412(개포동~삼성의료원)  122000614      23617
#
#                   역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 0        창경궁.서울대학교병원          1          0         0         0  ...
# ...

# %%
df_bus_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404944 entries, 0 to 404943
# Data columns (total 60 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사용년월        404944 non-null  int64
#  1   노선번호        404944 non-null  object
#  2   노선명         404944 non-null  object
#  3   표준ID        404944 non-null  object
#  4   버스정류장ARS번호  404944 non-null  object
#  5   역명          404944 non-null  object
#  6   00시승차총승객수   404944 non-null  int64
#  7   00시하차총승객수   404944 non-null  int64
#  8   1시승차총승객수    404944 non-null  int64
#  9   1시하차총승객수    404944 non-null  int64
#  10  2시승차총승객수    404944 non-null  int64
#  11  2시하차총승객수    404944 non-null  int64
#  12  3시승차총승객수    404944 non-null  int64
#  13  3시하차총승객수    404944 non-null  int64
#  14  4시승차총승객수    404944 non-null  int64
#  15  4시하차총승객수    404944 non-null  int64
#  16  5시승차총승객수    404944 non-null  int64
#  17  5시하차총승객수    404944 non-null  int64
# ...

# %%
df_bus_tmp.nunique()
# Out:
# 사용년월             12
# 노선번호            628
# 노선명             659
# 표준ID          10647
# 버스정류장ARS번호    10651
# 역명             6867
# 00시승차총승객수      1116
# 00시하차총승객수       826
# 1시승차총승객수        624
# 1시하차총승객수        493
# 2시승차총승객수        482
# 2시하차총승객수        406
# 3시승차총승객수        493
# 3시하차총승객수        394
# 4시승차총승객수       1085
# 4시하차총승객수        783
# 5시승차총승객수       1156
# 5시하차총승객수       1532
# 6시승차총승객수       1612
# 6시하차총승객수       2129
# 7시승차총승객수       2909
# 7시하차총승객수       3948
# 8시승차총승객수       3632
# 8시하차총승객수       4601
# 9시승차총승객수       2778
# 9시하차총승객수       3415
# 10시승차총승객수      1992
# 10시하차총승객수      2435
# 11시승차총승객수      1893
# 11시하차총승객수      2227
# 12시승차총승객수      2083
# 12시하차총승객수      2292
# 13시승차총승객수      2209
# 13시하차총승객수      2335
# 14시승차총승객수      2288
# 14시하차총승객수      2222
# 15시승차총승객수      2577
# 15시하차총승객수      2252
# 16시승차총승객수      2853
# 16시하차총승객수      2399
# 17시승차총승객수      3324
# 17시하차총승객수      2710
# 18시승차총승객수      4190
# 18시하차총승객수      3110
# 19시승차총승객수      3949
# ...

# %%
df_bus_tmp.head()
# Out:
#      사용년월 노선번호                   노선명       표준ID 버스정류장ARS번호           역명  \
# 0  202001  100        100번(하계동~용산구청)  100000002      01002  창경궁.서울대학교병원
# 1  202001  102         102번(상계동~동대문)  100000002      01002  창경궁.서울대학교병원
# 2  202001  104  104번(강북청소년수련관난나~숭례문)  100000002      01002  창경궁.서울대학교병원
# 3  202001  106         106번(의정부~동대문)  100000002      01002  창경궁.서울대학교병원
# 4  202001  140       140번(도봉산역~AT센터)  100000002      01002  창경궁.서울대학교병원
#
#    00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  22시승차총승객수  22시하차총승객수  \
# 0          1          0         0         0  ...         49         27
# 1          2          0         0         0  ...          8         22
# 2          0          0         0         0  ...         33         60
# 3          4         20         0         0  ...         30         14
# 4          0          0         0         0  ...         74         25
#
#    23시승차총승객수  23시하차총승객수      등록일자  ARS-ID         정류장명         X좌표        Y좌표  \
# ...

# %%
df_bus_tmp.columns
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
#        '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '등록일자', 'ARS-ID',
#        '정류장명', 'X좌표', 'Y좌표', '비고'],
#       dtype='object')

# %%
bus_tmp=df_bus_tmp[(df_bus_tmp.사용년월 > 202001) & (df_bus_tmp.사용년월 < 202007)]
bus_tmp.drop(['노선번호', '노선명','버스정류장ARS번호','등록일자', 'ARS-ID',
       '정류장명','비고'], axis=1, inplace=True)
# Out:
# C:\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
bus_tmp
# Out:
#           사용년월       표준ID           역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  \
# 17      202002  100000002  창경궁.서울대학교병원          0          0         0
# 18      202002  100000002  창경궁.서울대학교병원          0          1         0
# 19      202002  100000002  창경궁.서울대학교병원          0          0         0
# 20      202002  100000002  창경궁.서울대학교병원          5         13         0
# 21      202002  100000002  창경궁.서울대학교병원          0          0         0
# ...        ...        ...          ...        ...        ...       ...
# 404891  202006  124000186     상일동주몽재활원          0          0         0
# 404904  202006  124000187      상일동빌라단지          6         26         0
# 404905  202006  124000187      상일동빌라단지          0          0         0
# 404918  202006  124000188      상일동빌라단지          0          0         0
# 404919  202006  124000188      상일동빌라단지         13          7         0
#
#         1시하차총승객수  2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  20시승차총승객수  20시하차총승객수  \
# ...

# %%
import geopandas as gpd
import folium
import json
from geopandas import GeoSeries, GeoDataFrame, read_file
from shapely.geometry import Point, Polygon

# %%
df_bus_tmp = gpd.GeoDataFrame(bus_tmp, geometry=gpd.points_from_xy(bus_tmp['X좌표'],bus_tmp['Y좌표']))
df_bus_tmp.head(2)
# Out:
#       사용년월       표준ID           역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  \
# 17  202002  100000002  창경궁.서울대학교병원          0          0         0         0
# 18  202002  100000002  창경궁.서울대학교병원          0          1         0         0
#
#     2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  20시하차총승객수  21시승차총승객수  21시하차총승객수  \
# 17         0         0         0  ...         27         22         25
# 18         0         0         0  ...         40         16         36
#
#     22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수         X좌표        Y좌표  \
# 17         16         20         17          3  126.996566  37.579183
# 18          5         22          7         19  126.996566  37.579183
#
#                       geometry
# 17  POINT (126.99657 37.57918)
# 18  POINT (126.99657 37.57918)
#
# [2 rows x 54 columns]

# %%
df_bus_tmp.to_csv('df_bus_tmp.csv', encoding='cp949')

# %%
df_bus_tmp.to_file(driver='GeoJSON', filename ='df_bus_tmp.geojson')

# %%
df_bus_tmp.drop(['X좌표','Y좌표'],axis=1, inplace= True)

# %%
df_bus_tmp
# Out:
#           사용년월       표준ID           역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  \
# 17      202002  100000002  창경궁.서울대학교병원          0          0         0
# 18      202002  100000002  창경궁.서울대학교병원          0          1         0
# 19      202002  100000002  창경궁.서울대학교병원          0          0         0
# 20      202002  100000002  창경궁.서울대학교병원          5         13         0
# 21      202002  100000002  창경궁.서울대학교병원          0          0         0
# ...        ...        ...          ...        ...        ...       ...
# 404891  202006  124000186     상일동주몽재활원          0          0         0
# 404904  202006  124000187      상일동빌라단지          6         26         0
# 404905  202006  124000187      상일동빌라단지          0          0         0
# 404918  202006  124000188      상일동빌라단지          0          0         0
# 404919  202006  124000188      상일동빌라단지         13          7         0
#
#         1시하차총승객수  2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  19시하차총승객수  20시승차총승객수  \
# ...

# %%
df_bus_tmp.to_file(driver='GeoJSON', filename ='bus.geojson')

# %%
df_bus_tmp.to_csv('bus.csv', encoding='cp949')

# %%
##

# %%
# df = gpd.GeoDataFrame.from_file('df_bus_tmp.geojson')

# %%
df = pd.read_csv('df_bus_tmp.csv', encoding='cp949',index_col=0)

# %%
df.head(2)
# Out:
#       사용년월       표준ID           역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  \
# 17  202002  100000002  창경궁.서울대학교병원          0          0         0         0
# 18  202002  100000002  창경궁.서울대학교병원          0          1         0         0
#
#     2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  20시하차총승객수  21시승차총승객수  21시하차총승객수  \
# 17         0         0         0  ...         27         22         25
# 18         0         0         0  ...         40         16         36
#
#     22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수         X좌표        Y좌표  \
# 17         16         20         17          3  126.996566  37.579183
# 18          5         22          7         19  126.996566  37.579183
#
#                                 geometry
# 17  POINT (126.9965660023 37.5791830159)
# 18  POINT (126.9965660023 37.5791830159)
#
# [2 rows x 54 columns]

# %%
# df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
import datetime

# %%
df['사용년월'] = df['사용년월'].astype('str')
# df['사용년월'] = pd.to_datetime(df['사용년월'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160018 entries, 17 to 404919
# Data columns (total 54 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   사용년월       160018 non-null  object
#  1   표준ID       160018 non-null  int64
#  2   역명         160018 non-null  object
#  3   00시승차총승객수  160018 non-null  int64
#  4   00시하차총승객수  160018 non-null  int64
#  5   1시승차총승객수   160018 non-null  int64
#  6   1시하차총승객수   160018 non-null  int64
#  7   2시승차총승객수   160018 non-null  int64
#  8   2시하차총승객수   160018 non-null  int64
#  9   3시승차총승객수   160018 non-null  int64
#  10  3시하차총승객수   160018 non-null  int64
#  11  4시승차총승객수   160018 non-null  int64
#  12  4시하차총승객수   160018 non-null  int64
#  13  5시승차총승객수   160018 non-null  int64
#  14  5시하차총승객수   160018 non-null  int64
#  15  6시승차총승객수   160018 non-null  int64
#  16  6시하차총승객수   160018 non-null  int64
#  17  7시승차총승객수   160018 non-null  int64
#  18  7시하차총승객수   160018 non-null  int64
# ...

# %%
df['quarter'] = 0

# %%
df.head()
# Out:
#       사용년월       표준ID           역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  \
# 17  202002  100000002  창경궁.서울대학교병원          0          0         0         0
# 18  202002  100000002  창경궁.서울대학교병원          0          1         0         0
# 19  202002  100000002  창경궁.서울대학교병원          0          0         0         0
# 20  202002  100000002  창경궁.서울대학교병원          5         13         0         0
# 21  202002  100000002  창경궁.서울대학교병원          0          0         0         0
#
#     2시승차총승객수  2시하차총승객수  3시승차총승객수  ...  21시승차총승객수  21시하차총승객수  22시승차총승객수  \
# 17         0         0         0  ...         22         25         16
# 18         0         0         0  ...         16         36          5
# 19         0         0         0  ...         22         39         15
# 20         0         0         0  ...         23          6         20
# 21         0         0         0  ...         87         25         57
#
#     22시하차총승객수  23시승차총승객수  23시하차총승객수         X좌표        Y좌표  \
# ...

# %%
df = df.reset_index()

# %%
df.drop('index', axis=1, inplace=True)

# %%
for i in range(len(df)):
    if (df['사용년월'][i][5:] == '2') or (df['사용년월'][i][5:] == '3') :
        df['quarter'][i] = 1
    else : 
        df['quarter'][i] = 2
# Out:
# <ipython-input-90-b7ccea8655b3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'][i] = 1
# <ipython-input-90-b7ccea8655b3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'][i] = 2

# %%
df['quarter'].value_counts()
# Out:
# 2    90090
# 1    69928
# Name: quarter, dtype: int64

# %%
# 정류소명은 같은데 표준ID가 다름
# 좌표값과 매칭되는게 표준ID이므로 표준ID로 groupby
df.nunique()
# Out:
# 사용년월             5
# 표준ID         10645
# 역명            6766
# 00시승차총승객수      877
# 00시하차총승객수      696
# 1시승차총승객수       518
# 1시하차총승객수       420
# 2시승차총승객수       390
# 2시하차총승객수       352
# 3시승차총승객수       398
# 3시하차총승객수       330
# 4시승차총승객수       884
# 4시하차총승객수       653
# 5시승차총승객수       981
# 5시하차총승객수      1218
# 6시승차총승객수      1276
# 6시하차총승객수      1603
# 7시승차총승객수      2258
# 7시하차총승객수      2818
# 8시승차총승객수      2803
# 8시하차총승객수      3383
# 9시승차총승객수      2094
# 9시하차총승객수      2602
# 10시승차총승객수     1522
# 10시하차총승객수     1813
# 11시승차총승객수     1442
# 11시하차총승객수     1662
# 12시승차총승객수     1569
# 12시하차총승객수     1717
# 13시승차총승객수     1679
# 13시하차총승객수     1777
# 14시승차총승객수     1742
# 14시하차총승객수     1732
# 15시승차총승객수     1910
# 15시하차총승객수     1749
# 16시승차총승객수     2106
# 16시하차총승객수     1854
# 17시승차총승객수     2479
# 17시하차총승객수     2104
# 18시승차총승객수     3158
# 18시하차총승객수     2477
# 19시승차총승객수     2926
# 19시하차총승객수     2149
# 20시승차총승객수     2359
# 20시하차총승객수     1634
# 21시승차총승객수     2271
# 21시하차총승객수     1495
# ...

# %%
df['00시총승객수'] = df['00시승차총승객수'] + df['00시하차총승객수']
df['1시총승객수'] = df['1시승차총승객수'] + df['1시하차총승객수']
df['2시총승객수'] = df['2시승차총승객수'] + df['2시하차총승객수']
df['3시총승객수'] = df['3시승차총승객수'] + df['3시하차총승객수']
df['4시총승객수'] = df['4시승차총승객수'] + df['4시하차총승객수']
df['5시총승객수'] = df['5시승차총승객수'] + df['5시하차총승객수']
df['6시총승객수'] = df['6시승차총승객수'] + df['6시하차총승객수']
df['7시총승객수'] = df['7시승차총승객수'] + df['7시하차총승객수']
df['8시총승객수'] = df['8시승차총승객수'] + df['8시하차총승객수']
df['9시총승객수'] = df['9시승차총승객수'] + df['9시하차총승객수']
df['0시총승객수'] = df['10시승차총승객수'] + df['10시하차총승객수']
df['11시총승객수'] = df['11시승차총승객수'] + df['11시하차총승객수']
df['12시총승객수'] = df['12시승차총승객수'] + df['12시하차총승객수']
df['13시총승객수'] = df['13시승차총승객수'] + df['13시하차총승객수']
df['14시총승객수'] = df['14시승차총승객수'] + df['14시하차총승객수']
df['15시총승객수'] = df['15시승차총승객수'] + df['15시하차총승객수']
df['16시총승객수'] = df['16시승차총승객수'] + df['16시하차총승객수']
df['17시총승객수'] = df['17시승차총승객수'] + df['17시하차총승객수']
df['18시총승객수'] = df['18시승차총승객수'] + df['18시하차총승객수']
df['19시총승객수'] = df['19시승차총승객수'] + df['19시하차총승객수']
df['20시총승객수'] = df['20시승차총승객수'] + df['20시하차총승객수']
df['21시총승객수'] = df['21시승차총승객수'] + df['21시하차총승객수']
df['22시총승객수'] = df['22시승차총승객수'] + df['22시하차총승객수']
df['23시총승객수'] = df['23시승차총승객수'] + df['23시하차총승객수']
df.drop(['00시승차총승객수','00시하차총승객수','1시승차총승객수','1시하차총승객수','2시승차총승객수','2시하차총승객수','3시승차총승객수','3시하차총승객수','4시승차총승객수','4시하차총승객수','5시승차총승객수','5시하차총승객수','6시승차총승객수','6시하차총승객수','7시승차총승객수','7시하차총승객수','8시승차총승객수','8시하차총승객수','9시승차총승객수','9시하차총승객수','10시승차총승객수','10시하차총승객수','11시승차총승객수','11시하차총승객수','12시승차총승객수','12시하차총승객수','13시승차총승객수','13시하차총승객수','14시승차총승객수','14시하차총승객수','15시승차총승객수','15시하차총승객수','16시승차총승객수','16시하차총승객수','17시승차총승객수','17시하차총승객수','18시승차총승객수','18시하차총승객수','19시승차총승객수','19시하차총승객수','20시승차총승객수','20시하차총승객수','21시승차총승객수','21시하차총승객수','22시승차총승객수','22시하차총승객수','23시승차총승객수','23시하차총승객수'], axis=1, inplace=True)

# %%
df
# Out:
#           사용년월       표준ID           역명         X좌표        Y좌표  \
# 0       202002  100000002  창경궁.서울대학교병원  126.996566  37.579183
# 1       202002  100000002  창경궁.서울대학교병원  126.996566  37.579183
# 2       202002  100000002  창경궁.서울대학교병원  126.996566  37.579183
# 3       202002  100000002  창경궁.서울대학교병원  126.996566  37.579183
# 4       202002  100000002  창경궁.서울대학교병원  126.996566  37.579183
# ...        ...        ...          ...         ...        ...
# 160013  202006  124000186     상일동주몽재활원  127.163209  37.545746
# 160014  202006  124000187      상일동빌라단지  127.160119  37.545414
# 160015  202006  124000187      상일동빌라단지  127.160119  37.545414
# 160016  202006  124000188      상일동빌라단지  127.160085  37.545685
# 160017  202006  124000188      상일동빌라단지  127.160085  37.545685
#
#                                     geometry  quarter  00시총승객수  1시총승객수  \
# 0       POINT (126.9965660023 37.5791830159)        1        0       0
# 1       POINT (126.9965660023 37.5791830159)        1        1       0
# ...

# %%
df.drop(['역명','사용년월'], axis=1, inplace=True)

# %%
df = df.groupby(['quarter','geometry','표준ID', 'X좌표', 'Y좌표']).sum()

# %%
df
# Out:
#                                                                              00시총승객수  \
# quarter geometry                             표준ID      X좌표        Y좌표
# 1       POINT (126.797811 37.57845)          115000320 126.797811 37.578450       95
#         POINT (126.797978 37.57822)          115000321 126.797978 37.578220      106
#         POINT (126.798335 37.58182)          115000075 126.798335 37.581820       11
#         POINT (126.798863 37.56242)          115000298 126.798863 37.562420       28
#         POINT (126.798872 37.562433)         115000297 126.798872 37.562433        0
# ...                                                                              ...
# 2       POINT (127.1794 37.56811)            124000439 127.179400 37.568110        0
#         POINT (127.1794626974 37.5595533554) 124000341 127.179463 37.559553       30
#         POINT (127.1797196537 37.5595583711) 124000329 127.179720 37.559558     1729
# ...

# %%
df = df.reset_index()

# %%
df1=df.copy()

# %%
df1
# Out:
#        quarter                              geometry       표준ID         X좌표  \
# 0            1           POINT (126.797811 37.57845)  115000320  126.797811
# 1            1           POINT (126.797978 37.57822)  115000321  126.797978
# 2            1           POINT (126.798335 37.58182)  115000075  126.798335
# 3            1           POINT (126.798863 37.56242)  115000298  126.798863
# 4            1          POINT (126.798872 37.562433)  115000297  126.798872
# ...        ...                                   ...        ...         ...
# 21238        2             POINT (127.1794 37.56811)  124000439  127.179400
# 21239        2  POINT (127.1794626974 37.5595533554)  124000341  127.179463
# 21240        2  POINT (127.1797196537 37.5595583711)  124000329  127.179720
# 21241        2   POINT (127.1799002887 37.561716212)  124000339  127.179900
# 21242        2    POINT (127.18013794 37.5616924212)  124000338  127.180138
#
# ...

# %%
# geometry 형변환을 해준다
from shapely import wkt

df1['geometry'] = df1['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df1)

# %%
gdf
# Out:
#        quarter                    geometry       표준ID         X좌표        Y좌표  \
# 0            1  POINT (126.79781 37.57845)  115000320  126.797811  37.578450
# 1            1  POINT (126.79798 37.57822)  115000321  126.797978  37.578220
# 2            1  POINT (126.79833 37.58182)  115000075  126.798335  37.581820
# 3            1  POINT (126.79886 37.56242)  115000298  126.798863  37.562420
# 4            1  POINT (126.79887 37.56243)  115000297  126.798872  37.562433
# ...        ...                         ...        ...         ...        ...
# 21238        2  POINT (127.17940 37.56811)  124000439  127.179400  37.568110
# 21239        2  POINT (127.17946 37.55955)  124000341  127.179463  37.559553
# 21240        2  POINT (127.17972 37.55956)  124000329  127.179720  37.559558
# 21241        2  POINT (127.17990 37.56172)  124000339  127.179900  37.561716
# 21242        2  POINT (127.18014 37.56169)  124000338  127.180138  37.561692
#
# ...

# %%
gdf.to_file(driver='GeoJSON', filename='df_bus_quarter_geo.geojson')

# %%
gdf.to_csv('df_bus_quarter_geo.csv', encoding='cp949')

# %%
df = gpd.GeoDataFrame.from_file('df_bus_quarter_geo.geojson')
df
# Out:
#        quarter       표준ID  00시총승객수  1시총승객수  2시총승객수  3시총승객수  4시총승객수  5시총승객수  \
# 0            1  115000320       95      50      53      68     129      75
# 1            1  115000321      106     130     125      27      97      92
# 2            1  115000075       11       0       0       0       0     120
# 3            1  115000298       28       7       0       0       0       0
# 4            1  115000297        0       0       0       0     479     717
# ...        ...        ...      ...     ...     ...     ...     ...     ...
# 21238        2  124000439        0       0       0       0       4       7
# 21239        2  124000341       30       0       0       0     287    1317
# 21240        2  124000329     1729     269       0       0       0     125
# 21241        2  124000339       25       0       0       0     448    1652
# 21242        2  124000338      797      72       0       0       0     356
#
# ...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 21243 entries, 0 to 21242
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   quarter   21243 non-null  int64
#  1   표준ID      21243 non-null  int64
#  2   00시총승객수   21243 non-null  int64
#  3   1시총승객수    21243 non-null  int64
#  4   2시총승객수    21243 non-null  int64
#  5   3시총승객수    21243 non-null  int64
#  6   4시총승객수    21243 non-null  int64
#  7   5시총승객수    21243 non-null  int64
#  8   6시총승객수    21243 non-null  int64
#  9   7시총승객수    21243 non-null  int64
#  10  8시총승객수    21243 non-null  int64
#  11  9시총승객수    21243 non-null  int64
#  12  0시총승객수    21243 non-null  int64
#  13  11시총승객수   21243 non-null  int64
#  14  12시총승객수   21243 non-null  int64
#  15  13시총승객수   21243 non-null  int64
#  16  14시총승객수   21243 non-null  int64
#  17  15시총승객수   21243 non-null  int64
#  18  16시총승객수   21243 non-null  int64
#  19  17시총승객수   21243 non-null  int64
# ...

# %%
df_1=df.to_crs(epsg=3857)
df_1
# Out:
# C:\anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#        quarter       표준ID  00시총승객수  1시총승객수  2시총승객수  3시총승객수  4시총승객수  5시총승객수  \
# 0            1  115000320       95      50      53      68     129      75
# 1            1  115000321      106     130     125      27      97      92
# 2            1  115000075       11       0       0       0       0     120
# 3            1  115000298       28       7       0       0       0       0
# 4            1  115000297        0       0       0       0     479     717
# ...        ...        ...      ...     ...     ...     ...     ...     ...
# ...

# %%
df_1_geo_buffer = df_1.geometry.buffer(50)
df_1_geo_buffer
# Out:
# 0        POLYGON ((14115117.754 4520044.906, 14115117.5...
# 1        POLYGON ((14115136.345 4520012.600, 14115136.1...
# 2        POLYGON ((14115176.086 4520518.277, 14115175.8...
# 3        POLYGON ((14115234.862 4517793.529, 14115234.6...
# 4        POLYGON ((14115235.864 4517795.355, 14115235.6...
#                                ...
# 21238    POLYGON ((14157596.047 4518592.621, 14157595.8...
# 21239    POLYGON ((14157603.027 4517390.966, 14157602.7...
# 21240    POLYGON ((14157631.631 4517391.671, 14157631.3...
# 21241    POLYGON ((14157651.739 4517694.695, 14157651.4...
# 21242    POLYGON ((14157678.194 4517691.354, 14157677.9...
# Length: 21243, dtype: geometry

# %%
df_1['geometry'] = df_1_geo_buffer

# %%
df_1
# Out:
#        quarter       표준ID  00시총승객수  1시총승객수  2시총승객수  3시총승객수  4시총승객수  5시총승객수  \
# 0            1  115000320       95      50      53      68     129      75
# 1            1  115000321      106     130     125      27      97      92
# 2            1  115000075       11       0       0       0       0     120
# 3            1  115000298       28       7       0       0       0       0
# 4            1  115000297        0       0       0       0     479     717
# ...        ...        ...      ...     ...     ...     ...     ...     ...
# 21238        2  124000439        0       0       0       0       4       7
# 21239        2  124000341       30       0       0       0     287    1317
# 21240        2  124000329     1729     269       0       0       0     125
# 21241        2  124000339       25       0       0       0     448    1652
# 21242        2  124000338      797      72       0       0       0     356
#
# ...

# %%
comm_df_geo_poly = gpd.read_file('df_poly_286.geojson')
comm_df_geo_poly
# Out:
#                  상권명                                           geometry
# 0    서울 관악구 서울대입구역_1  POLYGON ((14132380.874 4506510.016, 14132472.9...
# 1               서림7길  POLYGON ((14131122.900 4504965.236, 14130993.2...
# 2       서울 관악구 신림역_4  POLYGON ((14129905.414 4506849.016, 14129748.6...
# 3             호암로24길  POLYGON ((14130583.054 4504768.704, 14130554.9...
# 4       서울 관악구 대학동_1  POLYGON ((14130716.868 4505103.626, 14130753.8...
# ..               ...                                                ...
# 281   서울 성북구 성신여대입구역  POLYGON ((14139744.767 4522081.907, 14139673.3...
# 282        강남구 논현역_1  POLYGON ((14140302.176 4509665.388, 14139928.3...
# 283           모래내로7길  POLYGON ((14127759.832 4518632.660, 14127763.5...
# 284             석촌시장  POLYGON ((14149657.028 4509182.741, 14149713.8...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
#
# [286 rows x 2 columns]

# %%
comm_df_geo_poly.nunique()
# Out:
# 상권명         286
# geometry    286
# dtype: int64

# %%
from geopandas import sjoin  # 공간데이터 결합

# %%
poly_in_bus= gpd.sjoin(comm_df_geo_poly, df_1, how='inner', op='intersects')
poly_in_bus.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-cf8bc51de09d> in <module>
# ----> 1 poly_in_bus= gpd.sjoin(df_1, comm_df_geo_poly, how='inner', op='intersects')
#       2 poly_in_bus.head()
#
# NameError: name 'df_1' is not defined

# %%
# 50m 277개
poly_in_bus.nunique()
# Out:
# 상권명             277
# geometry        277
# index_right    3361
# quarter           2
# 표준ID           1682
# 00시총승객수        1265
# 1시총승객수          623
# 2시총승객수          441
# 3시총승객수          417
# 4시총승객수          983
# 5시총승객수         1666
# 6시총승객수         2154
# 7시총승객수         2598
# 8시총승객수         2868
# 9시총승객수         2737
# 0시총승객수         2542
# 11시총승객수        2551
# 12시총승객수        2583
# 13시총승객수        2624
# 14시총승객수        2664
# 15시총승객수        2695
# 16시총승객수        2719
# 17시총승객수        2787
# 18시총승객수        2907
# 19시총승객수        2817
# 20시총승객수        2655
# 21시총승객수        2594
# 22시총승객수        2488
# 23시총승객수        2075
# dtype: int64

# %%
poly_in_bus_1=poly_in_bus.drop(['index_right','표준ID'], axis=1)
poly_in_bus_1
# Out:
#                  상권명                                           geometry  \
# 0    서울 관악구 서울대입구역_1  POLYGON ((14132380.874 4506510.016, 14132472.9...
# 86            관악로14길  POLYGON ((14132629.550 4506027.105, 14132591.5...
# 0    서울 관악구 서울대입구역_1  POLYGON ((14132380.874 4506510.016, 14132472.9...
# 86            관악로14길  POLYGON ((14132629.550 4506027.105, 14132591.5...
# 0    서울 관악구 서울대입구역_1  POLYGON ((14132380.874 4506510.016, 14132472.9...
# ..               ...                                                ...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
# 285             봉일시장  POLYGON ((14130813.787 4507033.037, 14130799.4...
#
#      quarter  00시총승객수  1시총승객수  2시총승객수  3시총승객수  4시총승객수  5시총승객수  6시총승객수  ...  \
# ...

# %%
poly_in_bus_1.sort_values(by=['quarter', '상권명'], inplace=True)

# %%
poly_in_bus_1
# Out:
#      상권명                                           geometry  quarter  00시총승객수  \
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1     1085
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1       50
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1      905
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1      265
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1       77
# ..   ...                                                ...      ...      ...
# 56  흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...        2        0
# 56  흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...        2     2212
# 56  흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...        2     1433
# 56  흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...        2       72
# 56  흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...        2     1087
#
# ...

# %%
poly_in_bus_1[poly_in_bus_1['상권명']=='가락시장']
# Out:
#      상권명                                           geometry  quarter  00시총승객수  \
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1     1085
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1       50
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1      905
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1      265
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1       77
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1     2816
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1        0
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1      429
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1     8358
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        1        0
# 71  가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...        2     1618
# ...

# %%
poly_in_bus_1.to_csv('50m.csv',encoding='cp949')

# %%
df = pd.read_csv('50m.csv',encoding='cp949',index_col=0)

# %%
df.columns
# Out:
# Index(['상권명', 'geometry', 'quarter', '00시총승객수', '1시총승객수', '2시총승객수', '3시총승객수',
#        '4시총승객수', '5시총승객수', '6시총승객수', '7시총승객수', '8시총승객수', '9시총승객수', '0시총승객수',
#        '11시총승객수', '12시총승객수', '13시총승객수', '14시총승객수', '15시총승객수', '16시총승객수',
#        '17시총승객수', '18시총승객수', '19시총승객수', '20시총승객수', '21시총승객수', '22시총승객수',
#        '23시총승객수'],
#       dtype='object')

# %%
count=df['상권명'].value_counts()

# %%
# 상권별로 교차하는 버스정류장 수 (버스정류장 50m반경)
count_df = pd.DataFrame({'상권명':count.index, 'count':count.values})
count_df
# Out:
#                         상권명  count
# 0                가산디지털단지역_3     82
# 1                  홍익대학교 주변     72
# 2    명동 남대문 북창동 다동 무교동 관광특구     64
# 3                가산디지털단지역_2     62
# 4                가산디지털단지역_1     48
# ..                      ...    ...
# 272                    석촌시장      2
# 273                 동작대로29길      2
# 274                   이태원시장      2
# 275                    보광시장      2
# 276                   낙성대시장      2
#
# [277 rows x 2 columns]

# %%
df = df.groupby(['quarter','상권명','geometry']).sum()

# %%
df
# Out:
#                                                                        00시총승객수  \
# quarter 상권명        geometry
# 1       가락시장       POLYGON ((14150649.52162249 4508185.679105095, ...    13985
#         가산디지털단지역_1 POLYGON ((14125050.80975904 4504896.327148256, ...      854
#         가산디지털단지역_2 POLYGON ((14124389.74013478 4506795.561698637, ...     3794
#         가산디지털단지역_3 POLYGON ((14124967.66159606 4506455.625721996, ...     5218
#         가재울로6길     POLYGON ((14129051.0227811 4519862.956843025, 1...     3152
# ...                                                                        ...
# 2       회기시장       POLYGON ((14143606.81761659 4521757.053233485, ...     5444
#         휘경로2길      POLYGON ((14144290.12840388 4522592.529482899, ...     4944
#         휘경로3길      POLYGON ((14144920.26173704 4522996.669896183, ...      738
#         흑석로9길      POLYGON ((14133148.71291306 4510157.940466819, ...      931
# ...

# %%
df.reset_index()
# Out:
#      quarter         상권명                                           geometry  \
# 0          1        가락시장  POLYGON ((14150649.52162249 4508185.679105095,...
# 1          1  가산디지털단지역_1  POLYGON ((14125050.80975904 4504896.327148256,...
# 2          1  가산디지털단지역_2  POLYGON ((14124389.74013478 4506795.561698637,...
# 3          1  가산디지털단지역_3  POLYGON ((14124967.66159606 4506455.625721996,...
# 4          1      가재울로6길  POLYGON ((14129051.0227811 4519862.956843025, ...
# ..       ...         ...                                                ...
# 549        2        회기시장  POLYGON ((14143606.81761659 4521757.053233485,...
# 550        2       휘경로2길  POLYGON ((14144290.12840388 4522592.529482899,...
# 551        2       휘경로3길  POLYGON ((14144920.26173704 4522996.669896183,...
# 552        2       흑석로9길  POLYGON ((14133148.71291306 4510157.940466819,...
# 553        2        흑석시장  POLYGON ((14133787.4119555 4510054.993576776, ...
#
# ...

# %%
df = df.reset_index()

# %%
df[df.상권명 == '가락시장']
# Out:
#      quarter   상권명                                           geometry  \
# 0          1  가락시장  POLYGON ((14150649.52162249 4508185.679105095,...
# 277        2  가락시장  POLYGON ((14150649.52162249 4508185.679105095,...
#
#      00시총승객수  1시총승객수  2시총승객수  3시총승객수  4시총승객수  5시총승객수  6시총승객수  ...  14시총승객수  \
# 0      13985    6850    3524    1930   10538   15879   25652  ...    35992
# 277    22357    8677    5560    3051   14084   21644   35414  ...    50983
#
#      15시총승객수  16시총승객수  17시총승객수  18시총승객수  19시총승객수  20시총승객수  21시총승객수  22시총승객수  \
# 0      38789    42734    50064    64768    46981    38939    37913    33911
# 277    56152    62562    69621    85048    64010    53052    52753    47406
#
#      23시총승객수
# 0      20898
# 277    30140
#
# [2 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   quarter   554 non-null    int64
#  1   상권명       554 non-null    object
#  2   geometry  554 non-null    object
#  3   00시총승객수   554 non-null    int64
#  4   1시총승객수    554 non-null    int64
#  5   2시총승객수    554 non-null    int64
#  6   3시총승객수    554 non-null    int64
#  7   4시총승객수    554 non-null    int64
#  8   5시총승객수    554 non-null    int64
#  9   6시총승객수    554 non-null    int64
#  10  7시총승객수    554 non-null    int64
#  11  8시총승객수    554 non-null    int64
#  12  9시총승객수    554 non-null    int64
#  13  0시총승객수    554 non-null    int64
#  14  11시총승객수   554 non-null    int64
#  15  12시총승객수   554 non-null    int64
#  16  13시총승객수   554 non-null    int64
#  17  14시총승객수   554 non-null    int64
#  18  15시총승객수   554 non-null    int64
#  19  16시총승객수   554 non-null    int64
# ...

# %%
from shapely import wkt

df['geometry'] = df['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df)

# %%
gdf
# Out:
#      quarter         상권명                                           geometry  \
# 0          1        가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...
# 1          1  가산디지털단지역_1  POLYGON ((14125050.810 4504896.327, 14125244.1...
# 2          1  가산디지털단지역_2  POLYGON ((14124389.740 4506795.562, 14124507.0...
# 3          1  가산디지털단지역_3  POLYGON ((14124967.662 4506455.626, 14125036.9...
# 4          1      가재울로6길  POLYGON ((14129051.023 4519862.957, 14129051.2...
# ..       ...         ...                                                ...
# 549        2        회기시장  POLYGON ((14143606.818 4521757.053, 14143607.7...
# 550        2       휘경로2길  POLYGON ((14144290.128 4522592.529, 14144294.7...
# 551        2       휘경로3길  POLYGON ((14144920.262 4522996.670, 14144888.6...
# 552        2       흑석로9길  POLYGON ((14133148.713 4510157.940, 14133187.0...
# 553        2        흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...
#
# ...

# %%
count_df['count'] = (count_df['count']/2).astype('int')

# %%
count_df
# Out:
#                         상권명  count
# 0                가산디지털단지역_3     41
# 1                  홍익대학교 주변     36
# 2    명동 남대문 북창동 다동 무교동 관광특구     32
# 3                가산디지털단지역_2     31
# 4                가산디지털단지역_1     24
# ..                      ...    ...
# 272                    석촌시장      1
# 273                 동작대로29길      1
# 274                   이태원시장      1
# 275                    보광시장      1
# 276                   낙성대시장      1
#
# [277 rows x 2 columns]

# %%
bus_50m_count = pd.merge(gdf, count_df, on='상권명', how='inner')
bus_50m_count
# Out:
#      quarter         상권명                                           geometry  \
# 0          1        가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...
# 1          2        가락시장  POLYGON ((14150649.522 4508185.679, 14150789.7...
# 2          1  가산디지털단지역_1  POLYGON ((14125050.810 4504896.327, 14125244.1...
# 3          2  가산디지털단지역_1  POLYGON ((14125050.810 4504896.327, 14125244.1...
# 4          1  가산디지털단지역_2  POLYGON ((14124389.740 4506795.562, 14124507.0...
# ..       ...         ...                                                ...
# 549        2       휘경로3길  POLYGON ((14144920.262 4522996.670, 14144888.6...
# 550        1       흑석로9길  POLYGON ((14133148.713 4510157.940, 14133187.0...
# 551        2       흑석로9길  POLYGON ((14133148.713 4510157.940, 14133187.0...
# 552        1        흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...
# 553        2        흑석시장  POLYGON ((14133787.412 4510054.994, 14133774.6...
#
# ...

# %%
bus_50m_count.to_file(driver='GeoJSON', filename='50m_poly_bus.geojson')

# %%
bus_50m_count.to_csv('50m_poly_bus.csv', encoding='cp949')
